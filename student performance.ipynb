# %%
#pip install pandas

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Amit'

# %%
import pandas as pd

# %%
path= 'C:\\Users\\Amit\\Downloads\\'

# %%
sp= pd.read_csv(path+"maths.csv")

# %%
sp.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
import sys

# %%
assert sys.version_info>=(3,5)

# %%
import sklearn
assert sklearn.__version__>="0.20"

# %%
# pip install numpy

# %%
import numpy as np
import os
import tarfile
import urllib
import pandas as pd

# %%
#pip install scikit-learn

# %%
#pip install matplotlib

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
print('Below are the details of the Student performance dataset:')
sp.info()
# Out:
# Below are the details of the Student performance dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
# ...

# %%
sp["age"].value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
sp.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sp.hist(bins=50, figsize=(20,15))
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots

# %%
import seaborn as sns
st=sp.loc[sp.school=="studytime"]
corr_mat_st=sp.corr()
corr_mat_st

plt.figure(figsize=(10,8))
plot=sns.heatmap(st.corr().round(2), annot= True)
# Out:
# C:\Users\Amit\anaconda3\lib\site-packages\seaborn\matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Amit\anaconda3\lib\site-packages\seaborn\matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
from scipy import stats
from scipy.stats import pearsonr
import seaborn as sns

# %%
sp.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
corr=sp.corr()
fig, ax=plt.subplots(figsize=(15,7))
sns.heatmap(corr, annot=True, ax=ax, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
#scatterplot
sp.plot(kind="scatter", x="G1", y="G2", figsize=(10,8), alpha=0.1);

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB(alpha=0.0, class_prior=[0.4,0.6])
model.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 model=MultinomialNB(alpha=0.0, class_prior=[0.4,0.6])
# ----> 3 model.fit(X,Y)
#
# NameError: name 'X' is not defined

# %%
sp.drop('address',axis=1, inplace=True)

# %%
sp.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18     GT3       A     4     4  at_home   teacher  course  ...
# 1     GP   F   17     GT3       T     1     1  at_home     other  course  ...
# 2     GP   F   15     LE3       T     1     1  at_home     other   other  ...
# 3     GP   F   15     GT3       T     4     2   health  services    home  ...
# 4     GP   F   16     GT3       T     3     3    other     other    home  ...
#
#   famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0      4         3      4     1    1      3        6   5   6   6
# 1      5         3      3     1    1      3        4   5   5   6
# 2      4         3      2     2    3      3       10   7   8  10
# 3      3         2      2     1    1      5        2  15  14  15
# 4      4         3      2     1    2      5        4   6  10  10
#
# [5 rows x 32 columns]

# %%
sp.drop('Mjob',axis=1, inplace=True)

# %%
sp.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu      Fjob  reason guardian  ...  \
# 0     GP   F   18     GT3       A     4     4   teacher  course   mother  ...
# 1     GP   F   17     GT3       T     1     1     other  course   father  ...
# 2     GP   F   15     LE3       T     1     1     other   other   mother  ...
# 3     GP   F   15     GT3       T     4     2  services    home   mother  ...
# 4     GP   F   16     GT3       T     3     3     other    home   father  ...
#
#    famrel  freetime  goout Dalc Walc health absences  G1  G2  G3
# 0       4         3      4    1    1      3        6   5   6   6
# 1       5         3      3    1    1      3        4   5   5   6
# 2       4         3      2    2    3      3       10   7   8  10
# 3       3         2      2    1    1      5        2  15  14  15
# 4       4         3      2    1    2      5        4   6  10  10
#
# [5 rows x 31 columns]

# %%
sp.drop('Fjob',axis=1, inplace=True)

# %%
sp.drop('address',axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 sp.drop('address',axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
sp.drop('reason',axis=1, inplace=True)

# %%
sp.drop('gaurdian',axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 sp.drop('gaurdian',axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
sp.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu guardian  traveltime  studytime  \
# 0     GP   F   18     GT3       A     4     4   mother           2          2
# 1     GP   F   17     GT3       T     1     1   father           1          2
# 2     GP   F   15     LE3       T     1     1   mother           1          2
# 3     GP   F   15     GT3       T     4     2   mother           1          3
# 4     GP   F   16     GT3       T     3     3   father           1          2
#
#    ...  famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0  ...       4        3     4    1    1      3        6   5   6   6
# 1  ...       5        3     3    1    1      3        4   5   5   6
# 2  ...       4        3     2    2    3      3       10   7   8  10
# 3  ...       3        2     2    1    1      5        2  15  14  15
# 4  ...       4        3     2    1    2      5        4   6  10  10
#
# [5 rows x 29 columns]

# %%
sp.drop('guardian',axis=1, inplace=True)

# %%
sp.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0     GP   F   18     GT3       A     4     4           2          2
# 1     GP   F   17     GT3       T     1     1           1          2
# 2     GP   F   15     LE3       T     1     1           1          2
# 3     GP   F   15     GT3       T     4     2           1          3
# 4     GP   F   16     GT3       T     3     3           1          2
#
#    failures  ... famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0         0  ...      4        3     4    1    1      3        6   5   6   6
# 1         0  ...      5        3     3    1    1      3        4   5   5   6
# 2         3  ...      4        3     2    2    3      3       10   7   8  10
# 3         0  ...      3        2     2    1    1      5        2  15  14  15
# 4         0  ...      4        3     2    1    2      5        4   6  10  10
#
# [5 rows x 28 columns]

# %%
school =dict([
    ('GP','0'),
    ('MS','1')
])

# %%
sp.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0     GP   F   18     GT3       A     4     4           2          2
# 1     GP   F   17     GT3       T     1     1           1          2
# 2     GP   F   15     LE3       T     1     1           1          2
# 3     GP   F   15     GT3       T     4     2           1          3
# 4     GP   F   16     GT3       T     3     3           1          2
#
#    failures  ... famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0         0  ...      4        3     4    1    1      3        6   5   6   6
# 1         0  ...      5        3     3    1    1      3        4   5   5   6
# 2         3  ...      4        3     2    2    3      3       10   7   8  10
# 3         0  ...      3        2     2    1    1      5        2  15  14  15
# 4         0  ...      4        3     2    1    2      5        4   6  10  10
#
# [5 rows x 28 columns]

# %%
sp.drop('sex',axis=1, inplace=True)

# %%
sp.drop('famsize',axis=1, inplace=True)

# %%
sp.drop('school',axis=1, inplace=True)

# %%
sp.head()
# Out:
#    age Pstatus  Medu  Fedu  traveltime  studytime  failures schoolsup famsup  \
# 0   18       A     4     4           2          2         0       yes     no
# 1   17       T     1     1           1          2         0        no    yes
# 2   15       T     1     1           1          2         3       yes     no
# 3   15       T     4     2           1          3         0        no    yes
# 4   16       T     3     3           1          2         0        no    yes
#
#   paid  ... famrel freetime goout Dalc Walc  health  absences  G1  G2  G3
# 0   no  ...      4        3     4    1    1       3         6   5   6   6
# 1   no  ...      5        3     3    1    1       3         4   5   5   6
# 2  yes  ...      4        3     2    2    3       3        10   7   8  10
# 3  yes  ...      3        2     2    1    1       5         2  15  14  15
# 4  yes  ...      4        3     2    1    2       5         4   6  10  10
#
# [5 rows x 25 columns]

# %%
sp.drop('schoolsup',axis=1, inplace=True)

# %%
sp.drop('famsup',axis=1, inplace=True)

# %%
sp.drop('paid',axis=1, inplace=True)

# %%
sp.drop('Pstatus',axis=1, inplace=True)

# %%
sp.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
sp.drop('activities',axis=1, inplace=True)

# %%
sp.drop('nursery',axis=1, inplace=True)

# %%
sp.drop('higher',axis=1, inplace=True)

# %%
sp.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
sp.drop('romantic',axis=1, inplace=True)

# %%
from scikitlearn import test_train_split()
# Out:
#   Input In [65]
#     from scikitlearn import test_train_split()
#                                             ^
# SyntaxError: invalid syntax

# %%
X=sp.iloc[:,1:15]

# %%
X
# Out:
#      Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0       4     4           2          2         0       4         3      4
# 1       1     1           1          2         0       5         3      3
# 2       1     1           1          2         3       4         3      2
# 3       4     2           1          3         0       3         2      2
# 4       3     3           1          2         0       4         3      2
# ..    ...   ...         ...        ...       ...     ...       ...    ...
# 390     2     2           1          2         2       5         5      4
# 391     3     1           2          1         0       2         4      5
# 392     1     1           1          1         3       5         5      3
# 393     3     2           3          1         0       4         4      1
# 394     1     1           1          1         0       3         2      3
#
#      Dalc  Walc  health  absences  G1  G2
# ...

# %%
y=sp.loc[:,"G3"]

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(X,y,test_size=.2)
# Out:
# [     Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
#  349     3     2           2          1         1       2         5      5
#  306     3     2           1          1         0       5         5      3
#  234     1     1           2          2         0       3         4      2
#  378     3     3           1          2         0       4         1      3
#  238     2     1           3          2         0       2         1      1
#  ..    ...   ...         ...        ...       ...     ...       ...    ...
#  99      4     3           1          3         0       5         3      5
#  148     4     4           1          1         0       3         3      2
#  381     2     1           2          1         0       4         4      3
#  192     1     2           2          2         0       4         4      4
#  339     3     2           1          2         0       4         3      3
#
#       Dalc  Walc  health  absences  G1  G2
# ...

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=.2)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# %%
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# C:\Users\Amit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Amit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72         9
#            5       0.00      0.00      0.00         1
#            6       0.40      1.00      0.57         4
#            7       0.00      0.00      0.00         1
#            8       0.40      0.22      0.29         9
# ...
